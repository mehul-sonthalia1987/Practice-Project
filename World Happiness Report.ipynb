# %% [markdown]
# Context
#
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %% [markdown]
# # Import necessary Python Modules

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Import the dataset

# %%
data = pd.read_csv('happiness_score_dataset.csv')
data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# # Data Exploration

# %%
data.shape
# Out:
# (158, 12)

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [raw]
# 1) Count
# No Null Values
# 2) Data Type
# Happiness Rank = Categorical
# Happiness Score, Standard Error, Economy, Family, Health, Freedom, Trust, Generosity, Dystopia Residual = Continous
# 3) STD (Standard Deviation) (STD should be less than the Mean)
# It is less for all the features
# 4) Quadrants (uniformity)

# %%
#Dropping Unwanted Columns
data = data.drop(columns = ['Happiness Rank'])

# %%
data.head()
# Out:
#        Country          Region  Happiness Score  Standard Error  \
# 0  Switzerland  Western Europe            7.587         0.03411
# 1      Iceland  Western Europe            7.561         0.04884
# 2      Denmark  Western Europe            7.527         0.03328
# 3       Norway  Western Europe            7.522         0.03880
# 4       Canada   North America            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# ...

# %%
data1=data.drop(columns = ['Country','Region'])
data1
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# # Visualizing & Analyzing the Data

# %%
plt.figure(figsize = (20,20), facecolor = 'white')
plotnumber = 1

for column in data1:
    if plotnumber<=12:
        ax = plt.subplot(3,4,plotnumber)
        sns.distplot(data1[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.tight_layout()

# %% [raw]
# The data distribution looks decent enough & there doesnt seem to be any skewness

# %% [raw]
# Let's observe the relation between independent variables & dependent variables

# %%
#divide the data set into features & label
y = data1['Happiness Score']
X = data1.drop(columns = ['Happiness Score'])

# %% [markdown]
# # Visualizing Relationship between Features & Label

# %%
plt.figure(figsize = (20,35), facecolor='white')
plotnumber = 1

for column in X:
    if plotnumber<=10:
        ax=plt.subplot(5,2,plotnumber)
        plt.scatter(X[column],y)
        plt.xlabel(column,fontsize=20)
        plt.ylabel("Happpiness Score", fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [raw]
# The relationship betwween the dependent and independent vairables look fairly linear.
# Thus, our linearity assuption is satisified.

# %% [markdown]
# # Using Linear Regression

# %%
#split data into Train & Test
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=245)

# %%
#Model installation & Training
regression = LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#y_pred (predicted values)
y_pred = regression.predict(x_test)

# %%
#MODEL EVALUATION
from sklearn.metrics import mean_absolute_error, mean_squared_error
#MAE
mean_absolute_error(y_test,y_pred)
# Out:
# 0.0002694124380182017

# %%
#MSE
mean_squared_error(y_test,y_pred)
# Out:
# 9.640654436220423e-08

# %%
#RMSE 
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 0.00031049403273203857

# %%
#Adjsuted R2 Score
regression.score(x_train,y_train)
# Out:
# 0.9999999446613984

# %%
#Let's check how well model fits the test data
regression.score(x_test,y_test)
# Out:
# 0.9999999272834836

# %% [markdown]
# # Predict the Happiness Score by given features

# %%
data1.tail(2)
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 156     0.19727            1.83302
# 157     0.16681            1.56726

# %%
print('Happiness Score is:', regression.predict([[0.08658,0.01530,0.41587,0.22396,0.11850,0.10062,0.19727,1.83302]]))
# Out:
# Happiness Score is: [2.90457028]

# %% [markdown]
# # RESULT

# %% [raw]
# RMSE = 0.00031049403273203857
# Adjsuted R2 Score = 0.9999999446613984
# Prediction of the Happiness score is absolutely correct.
